# %% [markdown]
# # Descriptive Statistics Problems
#
# ## Exercise 1 – How long are movie titles?
#
# In this exercise, you will apply descriptive statistics techniques to a real dataset: a database of 1000 popular movies from the IMDb website.
#
# From the title of each movie, you will:
# - Calculate the title length (in characters).
# - Obtain key statistical metrics: mean, median, mode, range, variance, standard deviation, skewness, and kurtosis.
# - Identify the longest and shortest titles.
# - Visualize the distribution of these lengths with a histogram and a density curve.

# %%
# Import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import skew, kurtosis, mode
import statistics as stats
import seaborn as sns

# Load IMDb dataset
url = "../assets/imdb_1000.csv"
df = pd.read_csv(url)
df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# 3            PG-13     Action       152
# 4                R      Crime       154
# ..             ...        ...       ...
# 974             PG     Comedy       116
# 975             PG  Adventure       118
# 976          PG-13     Action       138
# 977             PG     Horror       114
# 978              R      Crime       126
#
#                                            actors_list
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....
# ..                                                 ...
# 974  [u'Dustin Hoffman', u'Jessica Lange', u'Teri G...
# 975  [u'Michael J. Fox', u'Christopher Lloyd', u'Ma...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 977  [u'JoBeth Williams', u"Heather O'Rourke", u'Cr...
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
#
# [979 rows x 6 columns]

# %%
# Create a new column called 'title_length' with the length (number of characters) of each title
df['title_length']= df['title'].str.len()
df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list  title_length
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...            24
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']            13
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...            22
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...            15
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....            12

# %%
# Calculate mean, median, and mode of the 'title_length' column
mean_length = stats.mean(df['title_length'])
median_length = stats.median(df['title_length'])
mode_length = df['title_length'].mode()[0]

print (f'Mediana de title_length: ',mean_length)
print (f'Mediana de title_length: ',median_length)
print (f'Moda de title_length: ',mode_length)
# Out:
# Mediana de title_length:  15.481103166496425
# Mediana de title_length:  14
# Moda de title_length:  12

# %%
# Calculate the range, variance, and standard deviation of 'title_length'
range_length = df['title_length'].max() - df['title_length'].min()
variance_length = df['title_length'].var()
std_dev_length = df['title_length'].std()

print (f'Rango :',range_length)
print (f'Varianza :',variance_length) 
print (f'Desviacion estandar :',std_dev_length)
# Out:
# Rango : 67
# Varianza : 72.1067488840288
# Desviacion estandar : 8.491569282766807

# %%
# Calculate skewness and kurtosis of the 'title_length' column
skewness = skew(df['title_length'])
kurt = kurtosis(df['title_length'])

print ('Asimetria :', skewness)
print ('Curtosis', kurt)
# Out:
# Asimetria : 1.5229143965677572
# Curtosis 3.7867237597626007

# %%
# Print the shortest and longest title based on their length
shortest_title = df.loc[df['title_length'].idxmin(), 'title']
longest_title  = df.loc[df['title_length'].idxmax(), 'title']

print ('Titulo mas corto: ',shortest_title)
print ('Titulo mas largo: ',longest_title)
# Out:
# Titulo mas corto:  M
# Titulo mas largo:  Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb

# %%
# plot your results
plt.figure(figsize=(10,6))
sns.histplot(df['title_length'], kde=True, bins=20, edgecolor='black')
#Aplico lineas de media y mediana 
plt.axvline(df['title_length'].mean(), color='red', linestyle='dashed', linewidth=1)
plt.axvline(df['title_length'].median(), color='green', linestyle='dashed', linewidth=1)
plt.title('Distribución del largo de los títulos')
plt.xlabel('Número de caracteres')
plt.ylabel('Frecuencia')
plt.show()

# %% [markdown]
# ---
#
# ## Exercise 2 – Manual Calculation of Standard Deviation
#
# In this exercise, you will manually calculate the standard deviation by selecting five actual titles from the movie dataset you loaded earlier.

# %%
# Create a list with 5 actual values from df['title_length'], for example: [10, 13, 14, 18, 22]
list = [10, 13, 14, 18, 22]
list
# Out:
# [10, 13, 14, 18, 22]

# %%
# Calculate the mean of the 5 values
mean_list = sum(list) / len(list)

print (f'Media de la lista', mean_list)
# Out:
# Media de la lista 15.4

# %%
# Calculate the squared differences with respect to the mean
squared_diffs = [(x - mean_list) ** 2 for x in list]

print (f'Diferencias al cuadrado: ', squared_diffs)
# Out:
# Diferencias al cuadrado:  [29.160000000000004, 5.760000000000002, 1.960000000000001, 6.759999999999998, 43.559999999999995]

# %%
# Calculate the variance (average of the squared differences) and its square root to obtain the standard deviation
variance = sum(squared_diffs) / len(squared_diffs)  # Si es población
std_dev = variance ** 0.5

print (f'Varianza', variance)
print (f'Desviacion estandar: ',std_dev)
# Out:
# Varianza 17.439999999999998
# Desviacion estandar:  4.176122603564219
